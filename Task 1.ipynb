# %%
# pandas
import pandas as pd

# numpy
import numpy as np

# matplotlib
import matplotlib.pyplot as plt

# seaborn
import seaborn as sns

# %%
df = pd.read_csv("NYSERDA-Supported_Air_Source_Heat_Pump_Projects__2017-2019.csv")

# %%
#task1 
#show the first 10 data
df.head(10)
# Out:
#    Application Number           City    County State  Zip Code Gas Utility  \
# 0              122891       Flushing    Queens    NY     11385         NaN
# 1              122941  East Elmhurst    Queens    NY     11370         NaN
# 2              122947      Sunnyside    Queens    NY     11104         NaN
# 3              122948       New York  New York    NY     10029         NaN
# 4              122975    Olivebridge    Ulster    NY     12461         NaN
# 5              122999       Kingston    Ulster    NY     12401         NaN
# 6              123044        Warwick    Orange    NY     10990         NaN
# 7              123109    Churchville    Monroe    NY     14428         NaN
# 8              123117       Kingston    Ulster    NY     12401         NaN
# 9              123130       Kingston    Ulster    NY     12401         NaN
#
#                 Electric Utility  \
# 0            Consolidated Edison
# 1            Consolidated Edison
# 2            Consolidated Edison
# 3            Consolidated Edison
# 4  Central Hudson Gas & Electric
# 5  Central Hudson Gas & Electric
# 6            Orange and Rockland
# 7     Rochester Gas and Electric
# 8  Central Hudson Gas & Electric
# 9  Central Hudson Gas & Electric
#
#                                        Building Type  \
# 0  Single-family attached house such as a duplex,...
# 1  Single-family attached house such as a duplex,...
# 2  Single-family attached house such as a duplex,...
# 3  Apartment building or condominium with 2 to 4 ...
# 4                       Single-family detached house
# 5                       Single-family detached house
# 6                       Single-family detached house
# 7                       Single-family detached house
# 8                       Single-family detached house
# 9                       Single-family detached house
#
#              Home Conditioned Area Sqft  Percentage of sq. ft. conditioned  \
# 0  2,000 to less than 2,500 square feet                               0.90
# 1  1,000 to less than 1,500 square feet                               0.90
# 2  1,500 to less than 2,000 square feet                               0.60
# 3  3,000 to less than 4,000 square feet                               0.80
# 4  1,500 to less than 2,000 square feet                               0.75
# 5  1,500 to less than 2,000 square feet                               0.10
# 6  2,500 to less than 3,000 square feet                               0.20
# 7  1,500 to less than 2,000 square feet                               0.75
# 8  2,500 to less than 3,000 square feet                               0.50
# 9  1,500 to less than 2,000 square feet                               0.50
#
#    ... Primary Heating Fuel Type Primary Heating System Other Fuel Type  \
# 0  ...               Natural Gas              Hot water             NaN
# 1  ...               Natural Gas         Baseboard Heat             NaN
# 2  ...               Natural Gas         Baseboard Heat             NaN
# 3  ...               Natural Gas         Baseboard Heat             NaN
# 4  ...                       Oil     Central Forced Air             Oil
# 5  ...                   Propane         Baseboard Heat             NaN
# 6  ...                       Oil         Baseboard Heat             Oil
# 7  ...                  Electric         Baseboard Heat         Propane
# 8  ...               Natural Gas              Hot water             Oil
# 9  ...               Natural Gas              Hot water             NaN
#
#   Other Primary Heating System Primary Cooling System Age  \
# 0                          NaN                 Don't know
# 1                          NaN      Less than 2 years old
# 2                          NaN      Less than 2 years old
# 3                          NaN      Less than 2 years old
# 4                          NaN                 Don't know
# 5                          NaN                 Don't know
# 6                          NaN      Less than 2 years old
# 7                          NaN         10 to 14 years old
# 8                          NaN         10 to 14 years old
# 9                          NaN         10 to 14 years old
#
#   Total Project Cost (USD)  Total NYSERDA Incentive (USD)  \
# 0                     7500                           2000
# 1                    21759                           1000
# 2                     7962                            500
# 3                    58739                           1500
# 4                     9550                           1500
# 5                     4200                            500
# 6                     6850                            500
# 7                    14080                            500
# 8                     7700                           1000
# 9                     3900                           1000
#
#    Whole House Solution  Application Approval Date Application Status
# 0                 False                 07/13/2018             Closed
# 1                 False                 09/07/2018             Closed
# 2                 False                 09/07/2018             Closed
# 3                 False                 09/07/2018             Closed
# 4                 False                 07/13/2018             Closed
# 5                 False                 06/20/2018             Closed
# 6                 False                 06/20/2018             Closed
# 7                 False                 06/20/2018             Closed
# 8                 False                 06/20/2018             Closed
# 9                 False                 06/20/2018             Closed
#
# [10 rows x 21 columns]

# %%
#task2
#show the last 10 rows
df.tail(10)
# Out:
#       Application Number            City    County State  Zip Code  \
# 9720              228908  Middle Village    Queens    NY     11379
# 9721              228911      Whitestone    Queens    NY     11357
# 9722              228915   Fresh Meadows    Queens    NY     11365
# 9723              228919    Churchviller    Monroe    NY     14428
# 9724              228926        New York  New York    NY     10002
# 9725              228956        New York  New York    NY     10002
# 9726              228983        Brooklyn  New York    NY     11214
# 9727              228993      Queensbury    Warren    NY     12804
# 9728              228995          GROTON  New York    NY     13073
# 9729              229005         Corning    Monroe    NY     14830
#
#                      Gas Utility                 Electric Utility  \
# 9720               National Grid              Consolidated Edison
# 9721               National Grid              Consolidated Edison
# 9722                         NaN              Consolidated Edison
# 9723  Rochester Gas and Electric       Rochester Gas and Electric
# 9724                         NaN              Consolidated Edison
# 9725                         NaN              Consolidated Edison
# 9726                         NaN              Consolidated Edison
# 9727               National Grid                    National Grid
# 9728                         NaN  New York State Electric and Gas
# 9729         Corning Natural Gas  New York State Electric and Gas
#
#                                           Building Type  \
# 9720                       Single-family detached house
# 9721  Apartment building or condominium with 5 or mo...
# 9722  Apartment building or condominium with 5 or mo...
# 9723                       Single-family detached house
# 9724  Apartment building or condominium with 5 or mo...
# 9725  Apartment building or condominium with 5 or mo...
# 9726  Single-family attached house such as a duplex,...
# 9727                       Single-family detached house
# 9728                       Single-family detached house
# 9729                       Single-family detached house
#
#                 Home Conditioned Area Sqft  Percentage of sq. ft. conditioned  \
# 9720  1,500 to less than 2,000 square feet                               0.30
# 9721           Less than 1,000 square feet                               0.70
# 9722           Less than 1,000 square feet                               0.50
# 9723  2,000 to less than 2,500 square feet                               0.20
# 9724  1,000 to less than 1,500 square feet                               0.80
# 9725  1,000 to less than 1,500 square feet                               0.80
# 9726  3,000 to less than 4,000 square feet                               0.70
# 9727  2,000 to less than 2,500 square feet                               0.45
# 9728  1,500 to less than 2,000 square feet                               1.00
# 9729             4,000 or more square feet                               0.25
#
#       ... Primary Heating Fuel Type   Primary Heating System Other Fuel Type  \
# 9720  ...               Natural Gas                    Steam             NaN
# 9721  ...               Natural Gas                    Steam             NaN
# 9722  ...               Natural Gas     Air-Source Heat Pump             NaN
# 9723  ...               Natural Gas       Central Forced Air             NaN
# 9724  ...               Natural Gas     Air-Source Heat Pump             NaN
# 9725  ...               Natural Gas     Air-Source Heat Pump             NaN
# 9726  ...               Natural Gas                Hot water             NaN
# 9727  ...               Natural Gas       Central Forced Air             NaN
# 9728  ...                  Electric  Ground Source Heat Pump             NaN
# 9729  ...               Natural Gas       Central Forced Air             NaN
#
#      Other Primary Heating System Primary Cooling System Age  \
# 9720                          NaN                 Don't know
# 9721                          NaN                 Don't know
# 9722                          NaN                        NaN
# 9723                          NaN         10 to 14 years old
# 9724                          NaN                        NaN
# 9725                          NaN                        NaN
# 9726                          NaN                        NaN
# 9727                          NaN           5 to 9 years old
# 9728                          NaN                        NaN
# 9729                          NaN                 Don't know
#
#      Total Project Cost (USD)  Total NYSERDA Incentive (USD)  \
# 9720                     6500                            500
# 9721                     7295                            500
# 9722                     1300                            500
# 9723                     3830                            500
# 9724                     2800                            500
# 9725                     2800                            500
# 9726                     8300                           1000
# 9727                    12914                            500
# 9728                     4100                           4000
# 9729                     7980                            500
#
#       Whole House Solution  Application Approval Date Application Status
# 9720                 False                 12/26/2019             Closed
# 9721                 False                 12/26/2019             Closed
# 9722                 False                 12/26/2019             Closed
# 9723                 False                 12/26/2019             Closed
# 9724                 False                 12/26/2019             Closed
# 9725                 False                 12/26/2019             Closed
# 9726                 False                 12/26/2019             Closed
# 9727                 False                 12/26/2019             Closed
# 9728                  True                 12/26/2019             Closed
# 9729                 False                 12/26/2019             Closed
#
# [10 rows x 21 columns]

# %%
#task 3
#show the size of the data
df.shape
# Out:
# (9730, 21)

# %%
df.head(3)
# Out:
#    Application Number           City  County State  Zip Code Gas Utility  \
# 0              122891       Flushing  Queens    NY     11385         NaN
# 1              122941  East Elmhurst  Queens    NY     11370         NaN
# 2              122947      Sunnyside  Queens    NY     11104         NaN
#
#       Electric Utility                                      Building Type  \
# 0  Consolidated Edison  Single-family attached house such as a duplex,...
# 1  Consolidated Edison  Single-family attached house such as a duplex,...
# 2  Consolidated Edison  Single-family attached house such as a duplex,...
#
#              Home Conditioned Area Sqft  Percentage of sq. ft. conditioned  \
# 0  2,000 to less than 2,500 square feet                                0.9
# 1  1,000 to less than 1,500 square feet                                0.9
# 2  1,500 to less than 2,000 square feet                                0.6
#
#    ... Primary Heating Fuel Type Primary Heating System Other Fuel Type  \
# 0  ...               Natural Gas              Hot water             NaN
# 1  ...               Natural Gas         Baseboard Heat             NaN
# 2  ...               Natural Gas         Baseboard Heat             NaN
#
#   Other Primary Heating System Primary Cooling System Age  \
# 0                          NaN                 Don't know
# 1                          NaN      Less than 2 years old
# 2                          NaN      Less than 2 years old
#
#   Total Project Cost (USD)  Total NYSERDA Incentive (USD)  \
# 0                     7500                           2000
# 1                    21759                           1000
# 2                     7962                            500
#
#    Whole House Solution  Application Approval Date Application Status
# 0                 False                 07/13/2018             Closed
# 1                 False                 09/07/2018             Closed
# 2                 False                 09/07/2018             Closed
#
# [3 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Application Number', 'City', 'County', 'State', 'Zip Code',
#        'Gas Utility', 'Electric Utility', 'Building Type',
#        'Home Conditioned Area Sqft', 'Percentage of sq. ft. conditioned',
#        'Building Year Built', 'Primary Heating Fuel Type',
#        'Primary Heating System', 'Other Fuel Type',
#        'Other Primary Heating System', 'Primary Cooling System Age',
#        'Total Project Cost (USD)', 'Total NYSERDA Incentive (USD)',
#        'Whole House Solution', 'Application Approval Date',
#        'Application Status'],
#       dtype='object')

# %%
# Sample data creation (In practice, load your actual dataset)
data = {
    'Application Number': range(1, 101),
    'City': np.random.choice(['CityA', 'CityB', 'CityC'], 100),
    'County': np.random.choice(['CountyA', 'CountyB', 'CountyC'], 100),
    'State': np.random.choice(['StateA', 'StateB'], 100),
    'Zip Code': np.random.randint(10000, 99999, 100),
    'Gas Utility': np.random.choice(['Utility1', 'Utility2'], 100),
    'Electric Utility': np.random.choice(['Utility1', 'Utility2'], 100),
    'Building Type': np.random.choice(['Residential', 'Commercial'], 100),
    'Home Conditioned Area Sqft': np.random.randint(500, 5000, 100),
    'Percentage of sq. ft. conditioned': np.random.uniform(50, 100, 100),
    'Building Year Built': np.random.randint(1900, 2020, 100),
    'Primary Heating Fuel Type': np.random.choice(['Gas', 'Electric', 'Oil'], 100),
    'Primary Heating System': np.random.choice(['SystemA', 'SystemB'], 100),
    'Other Fuel Type': np.random.choice(['TypeA', 'TypeB', 'None'], 100),
    'Other Primary Heating System': np.random.choice(['SystemA', 'SystemB', 'None'], 100),
    'Primary Cooling System Age': np.random.randint(0, 30, 100),
    'Total Project Cost (USD)': np.random.uniform(1000, 50000, 100),
    'Total NYSERDA Incentive (USD)': np.random.uniform(500, 10000, 100),
    'Whole House Solution': np.random.choice(['Yes', 'No'], 100),
    'Application Approval Date': pd.date_range(start='1/1/2020', periods=100, freq='M'),
    'Application Status': np.random.choice(['Approved', 'Pending', 'Denied'], 100)
}

df = pd.DataFrame(data)

# %%
# Display the first few rows of the dataset
print(df.head())
# Out:
#    Application Number   City   County   State  Zip Code Gas Utility  \
# 0                   1  CityA  CountyA  StateB     51078    Utility2
# 1                   2  CityC  CountyC  StateA     74953    Utility1
# 2                   3  CityA  CountyC  StateA     54795    Utility2
# 3                   4  CityA  CountyB  StateA     64165    Utility1
# 4                   5  CityB  CountyC  StateA     73578    Utility1
#
#   Electric Utility Building Type  Home Conditioned Area Sqft  \
# 0         Utility2    Commercial                         690
# 1         Utility1    Commercial                        2900
# 2         Utility2    Commercial                        2308
# 3         Utility2    Commercial                        3038
# 4         Utility2   Residential                         899
#
#    Percentage of sq. ft. conditioned  ...  Primary Heating Fuel Type  \
# 0                          60.596721  ...                   Electric
# 1                          84.547768  ...                        Oil
# 2                          54.863043  ...                        Gas
# 3                          73.553716  ...                        Oil
# 4                          97.261103  ...                        Oil
#
#   Primary Heating System Other Fuel Type Other Primary Heating System  \
# 0                SystemA            None                         None
# 1                SystemA            None                      SystemB
# 2                SystemA           TypeA                      SystemB
# 3                SystemB           TypeA                      SystemA
# 4                SystemA           TypeB                      SystemB
#
#   Primary Cooling System Age  Total Project Cost (USD)  \
# 0                         25              33616.485320
# 1                         22              46537.825211
# 2                         13               4863.327650
# 3                          3              38490.079207
# 4                         19               8326.661504
#
#    Total NYSERDA Incentive (USD)  Whole House Solution  \
# 0                    1263.807749                    No
# 1                    6520.641930                   Yes
# 2                    4922.495330                    No
# 3                    2447.992435                   Yes
# 4                    7095.376970                   Yes
#
#   Application Approval Date Application Status
# 0                2020-01-31             Denied
# 1                2020-02-29             Denied
# 2                2020-03-31           Approved
# 3                2020-04-30           Approved
# 4                2020-05-31            Pending
#
# [5 rows x 21 columns]

# %%
# Summary statistics and info
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Application Number                 100 non-null    int64
#  1   City                               100 non-null    object
#  2   County                             100 non-null    object
#  3   State                              100 non-null    object
#  4   Zip Code                           100 non-null    int32
#  5   Gas Utility                        100 non-null    object
#  6   Electric Utility                   100 non-null    object
#  7   Building Type                      100 non-null    object
#  8   Home Conditioned Area Sqft         100 non-null    int32
#  9   Percentage of sq. ft. conditioned  100 non-null    float64
#  10  Building Year Built                100 non-null    int32
#  11  Primary Heating Fuel Type          100 non-null    object
#  12  Primary Heating System             100 non-null    object
#  13  Other Fuel Type                    100 non-null    object
#  14  Other Primary Heating System       100 non-null    object
#  15  Primary Cooling System Age         100 non-null    int32
#  16  Total Project Cost (USD)           100 non-null    float64
#  17  Total NYSERDA Incentive (USD)      100 non-null    float64
#  18  Whole House Solution               100 non-null    object
#  19  Application Approval Date          100 non-null    datetime64[ns]
#  20  Application Status                 100 non-null    object
# dtypes: datetime64[ns](1), float64(3), int32(4), int64(1), object(12)
# memory usage: 15.0+ KB
# None
#        Application Number      Zip Code  Home Conditioned Area Sqft  \
# count          100.000000    100.000000                  100.000000
# mean            50.500000  59049.590000                 2707.710000
# min              1.000000  11177.000000                  514.000000
# 25%             25.750000  43848.750000                 1696.750000
# 50%             50.500000  60277.000000                 2693.500000
# 75%             75.250000  77618.250000                 3804.250000
# max            100.000000  97633.000000                 4999.000000
# std             29.011492  23314.751729                 1323.260973
#
#        Percentage of sq. ft. conditioned  Building Year Built  \
# count                         100.000000           100.000000
# mean                           75.466492          1964.470000
# min                            50.081524          1907.000000
# 25%                            63.902369          1933.750000
# 50%                            75.687934          1967.500000
# 75%                            86.961750          1991.750000
# max                            99.353300          2017.000000
# std                            14.340372            32.592202
#
#        Primary Cooling System Age  Total Project Cost (USD)  \
# count                  100.000000                100.000000
# mean                    12.660000              25980.375887
# min                      0.000000               1228.974628
# 25%                      3.000000              13232.080270
# 50%                     12.000000              29799.643271
# 75%                     20.250000              38173.240603
# max                     29.000000              49963.585109
# std                      9.297789              15044.467836
#
#        Total NYSERDA Incentive (USD) Application Approval Date
# count                     100.000000                       100
# mean                     5836.006924       2024-03-15 18:28:48
# min                       522.882495       2020-01-31 00:00:00
# 25%                      3066.821098       2022-02-21 00:00:00
# 50%                      6493.267500       2024-03-15 12:00:00
# 75%                      8319.819363       2026-04-07 12:00:00
# max                      9937.732437       2028-04-30 00:00:00
# std                      2966.819558                       NaN

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Application Number                   0
# City                                 0
# County                               0
# State                                0
# Zip Code                             0
# Gas Utility                          0
# Electric Utility                     0
# Building Type                        0
# Home Conditioned Area Sqft           0
# Percentage of sq. ft. conditioned    0
# Building Year Built                  0
# Primary Heating Fuel Type            0
# Primary Heating System               0
# Other Fuel Type                      0
# Other Primary Heating System         0
# Primary Cooling System Age           0
# Total Project Cost (USD)             0
# Total NYSERDA Incentive (USD)        0
# Whole House Solution                 0
# Application Approval Date            0
# Application Status                   0
# dtype: int64

# %%
# Data Cleaning
df.fillna(method='ffill', inplace=True)

# %%
# Visualize Data Distribution

# %%
# Histograms for numerical features
df.hist(bins=20, figsize=(20, 15))
plt.suptitle('Histograms of Numerical Features', fontsize=20)
plt.show()

# %%
# Count plots for categorical features
plt.figure(figsize=(15, 10))
sns.countplot(y='City', data=df)
plt.title('Count Plot for City', fontsize=15)
plt.show()

# %%
sns.countplot(y='Building Type', data=df)
plt.title('Count Plot for Building Type', fontsize=15)
plt.show()

# %%
sns.countplot(y='Primary Heating Fuel Type', data=df)
plt.title('Count Plot for Primary Heating Fuel Type', fontsize=15)
plt.show()

# %%
# Analyze Relationships and Correlations

# %%
# Pairplot for numerical features
sns.pairplot(df[['Home Conditioned Area Sqft', 'Percentage of sq. ft. conditioned', 'Primary Cooling System Age', 'Total Project Cost (USD)', 'Total NYSERDA Incentive (USD)']])
plt.suptitle('Pairplot of Numerical Features', y=1.02)
plt.show()
# Out:
# C:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Scatter plot between 'Total Project Cost (USD)' and 'Total NYSERDA Incentive (USD)'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Total Project Cost (USD)', y='Total NYSERDA Incentive (USD)', data=df)
plt.title('Scatter Plot between Total Project Cost and Total NYSERDA Incentive', fontsize=15)
plt.xlabel('Total Project Cost (USD)', fontsize=12)
plt.ylabel('Total NYSERDA Incentive (USD)', fontsize=12)
plt.show()

# %%
# Scatter plot between 'Home Conditioned Area Sqft' and 'Total Project Cost (USD)'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Home Conditioned Area Sqft', y='Total Project Cost (USD)', data=df)
plt.title('Scatter Plot between Home Conditioned Area Sqft and Total Project Cost', fontsize=15)
plt.xlabel('Home Conditioned Area Sqft', fontsize=12)
plt.ylabel('Total Project Cost (USD)', fontsize=12)
plt.show()

# %%
# Select only numeric columns for correlation heatmap
numeric_columns = df.select_dtypes(include=[np.number]).columns
plt.figure(figsize=(12, 8))
sns.heatmap(df[numeric_columns].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap', fontsize=20)
plt.show()

# %%
# Detect Outliers

# %%
# Boxplot to detect outliers in numerical features
plt.figure(figsize=(15, 10))
sns.boxplot(data=df[['Home Conditioned Area Sqft', 'Percentage of sq. ft. conditioned', 'Primary Cooling System Age', 'Total Project Cost (USD)', 'Total NYSERDA Incentive (USD)']], orient='h')
plt.title('Boxplot for Outlier Detection')
plt.show()

# %% [markdown]
# # THE END
